# %% [markdown]
# ### Requests before dialogs

# %%
import glob, os
import re
import functools
import pickle

import pandas as pd
import numpy as np

import gensim
from gensim.models import LdaModel
from gensim.corpora import Dictionary
from gensim.models import Phrases

import natasha
from natasha import NamesExtractor

import pymorphy2
morph = pymorphy2.MorphAnalyzer()

import nltk
from nltk.tokenize import RegexpTokenizer
nltk.download('wordnet')
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/alisa.khoroshavina/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/alisa.khoroshavina/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def detectLang(string): # TODO: remove ','
    stringRu = "".join(re.sub('([A-Za-z]*)', ' ', string).split())
    stringEn = "".join(re.sub('([А-Яа-я]*)', ' ', string).split())
    if stringRu >= stringEn:
        return 'RU'
    else:
        return 'EN'

# %%
#lemmatization
def lemm(word):
    if detectLang(word) == 'EN':
        return nltk.stem.WordNetLemmatizer().lemmatize(word.lower())
    else:
        return morph.parse(word.lower())[0].normal_form

# %%
def extractNames(text):
    extractor = NamesExtractor()
    matches = extractor(text)
    names = []
    for match in matches:
        start, stop = match.span
        names += [lemm(name) for name in text[start:stop].split()]
    names = list(set(names)) # remove duplicates
    return names

# %%
def removeNum(string):
    return ''.join(re.sub('[0-9]*', '', string))

# %%
def nouns(word):
    p = morph.parse(word)[0]
    if 'NOUN' in p.tag:
        return True
    else:
        return False

# %%
noise = stopwords.words('russian') + stopwords.words('english')

with open('/home/alisa.khoroshavina/sw.txt', 'r', encoding='utf-8') as f:
    sw = f.readlines()
    
noise += sw

print(len(noise))
# Out:
# 483

# %%
files = []
os.chdir("/home/alisa.khoroshavina/year.csv/")
for file in glob.glob("*.csv"):
    files.append(file)

# %%
len(files)
# Out:
# 16

# %%
df = pd.read_csv(files[0], sep=',', names = list(range(0,5)), encoding='utf-8')
for i in range(1, len(files)):
    df = df.append(pd.read_csv(files[i], sep=',', names = list(range(0,5)), encoding='utf-8'))

# %%
#df.head()

# %%
#df.tail()

# %%
df.shape
# Out:
# (4042325, 5)

# %%
texts = list(df[3])

# %%
# preprocessing
tokenizer = RegexpTokenizer(r'\w+')
for i in range(len(texts)):
    texts[i] = removeNum(str(texts[i])).lower() 
    texts[i] = tokenizer.tokenize(texts[i])

# %%
txt = [[lemm(token) for token in doc if (nouns(token)) and (len(token) > 3)] for doc in texts]

docs = [[token for token in doc if token not in noise] for doc in txt]

# %%
"""
# Add bigrams and trigrams to docs (only ones that appear 20 times or more).
bigram = Phrases(docs, min_count=20)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)
"""
# Out:
# "\n# Add bigrams and trigrams to docs (only ones that appear 20 times or more).\nbigram = Phrases(docs, min_count=20)\nfor idx in range(len(docs)):\n    for token in bigram[docs[idx]]:\n        if '_' in token:\n            # Token is a bigram, add to document.\n            docs[idx].append(token)\n"

# %%
# Create a dictionary representation of the documents.
dictionary = Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=20, no_above=0.5)

# BOW representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]
#gensim.corpora.Dictionary.save(dictionary, 'dictionary.dict')

print('file %d' %i)                            
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# file 4042324
# Number of unique tokens: 7748
# Number of documents: 4042325

# %%
# Train LDA model.
num_topics = 42
chunksize = 2000
passes = 40
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

# %time model = LdaModel(corpus=corpus, id2word=id2word, chunksize=chunksize, \
                       alpha='auto', eta='auto', \
                       iterations=iterations, num_topics=num_topics, \
                       passes=passes, eval_every=eval_every)

top_topics = model.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
# Out:
# CPU times: user 4d 4h 3min 30s, sys: 6h 39min 28s, total: 4d 10h 42min 59s
# Wall time: 7h 56min 12s

# %%
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -14.4681.
# [([(0.3378162, 'группа'),
#    (0.13179298, 'вопрос'),
#    (0.1046485, 'видео'),
#    (0.09667732, 'музыка'),
#    (0.08376844, 'тема'),
#    (0.05710413, 'администрация'),
#    (0.04365888, 'администратор'),
#    (0.036828127, 'взлом'),
#    (0.029506786, 'минута'),
#    (0.014823727, 'описание'),
#    (0.014069037, 'создание'),
#    (0.0111717405, 'загрузка'),
#    (0.00858618, 'ник'),
#    (0.008196409, 'язык'),
#    (0.0050249365, 'вконтакте'),
#    (0.0032898774, 'свет'),
#    (0.0031977184, 'опрос'),
#    (0.0030309225, 'простой'),
#    (0.0018451993, 'обработка'),
#    (0.0016048258, 'рамочка')],
#   -8.134058484859032),
#  ([(0.18112387, 'фамилия'),
#    (0.10755301, 'паспорт'),
#    (0.086504675, 'фон'),
#    (0.08298527, 'уведомление'),
#    (0.065878116, 'личность'),
#    (0.060616896, 'ирина'),
#    (0.051816683, 'кошелёк'),
#    (0.048441235, 'яндекс'),
#    (0.04125461, 'начало'),
#    (0.039864883, 'память'),
#    (0.031057535, 'категория'),
#    (0.027767194, 'ребята'),
#    (0.027520483, 'олег'),
#    (0.02533565, 'юлий'),
#    (0.022228917, 'билайн'),
#    (0.017991947, 'зарание'),
#    (0.017373797, 'внук'),
#    (0.014389344, 'введение'),
#    (0.013010606, 'установка'),
#    (0.011741258, 'чистка')],
#   -8.140952250181943),
#  ([(0.23108014, 'ответ'),
#    (0.16074954, 'мошенник'),
#    (0.07393257, 'обращение'),
#    (0.07392846, 'кнопка'),
#    (0.05889682, 'получение'),
#    (0.055604618, 'комп'),
#    (0.05045779, 'акция'),
#    (0.045832638, 'использование'),
#    (0.043120064, 'цель'),
#    (0.03295264, 'смартфон'),
#    (0.022839546, 'настоящее'),
#    (0.022407155, 'бабушка'),
#    (0.02056887, 'новость'),
#    (0.019401362, 'публикация'),
#    (0.017467434, 'регион'),
#    (0.01582945, 'андроид'),
#    (0.012330087, 'плеер'),
#    (0.011584166, 'указание'),
#    (0.008900346, 'флёша'),
#    (0.0068352064, 'прашу')],
#   -8.529427832908567),
#  ([(0.2621126, 'востановление'),
#    (0.1174123, 'майла'),
#    (0.10744936, 'праздник'),
#    (0.076551475, 'светлана'),
#    (0.061741993, 'результат'),
#    (0.060724188, 'окно'),
#    (0.04464635, 'замена'),
#    (0.03692208, 'тип'),
#    (0.032944564, 'мейл'),
#    (0.031201897, 'период'),
#    (0.027869742, 'честь'),
#    (0.021084769, 'требование'),
#    (0.019336006, 'вячеслав'),
#    (0.0188565, 'опция'),
#    (0.018798366, 'санкт'),
#    (0.018702798, 'петербург'),
#    (0.012867261, 'новосибирск'),
#    (0.008930779, 'совесть'),
#    (0.00848077, 'прозьба'),
#    (0.005122254, 'соколов')],
#   -11.175563612073528),
#  ([(0.45672396, 'фото'),
#    (0.20696408, 'адрес'),
#    (0.0957564, 'связь'),
#    (0.059433952, 'сеть'),
#    (0.043135922, 'симкарта'),
#    (0.03791487, 'чужое'),
#    (0.022523845, 'сын'),
#    (0.020304326, 'скрин'),
#    (0.014934706, 'сестра'),
#    (0.012602793, 'женщина'),
#    (0.011889117, 'сторона'),
#    (0.0073781116, 'сотрудник'),
#    (0.0045041367, 'республика'),
#    (0.0036490613, 'территория'),
#    (0.0015005296, 'вложение'),
#    (1.0140975e-07, 'выстоновление'),
#    (1.0140975e-07, 'гениталия'),
#    (1.0140975e-07, 'майкл'),
#    (1.0140975e-07, 'сет'),
#    (1.0140975e-07, 'фейс')],
#   -11.397474150922186),
#  ([(0.3477408, 'время'),
#    (0.12523161, 'уважение'),
#    (0.12053692, 'срок'),
#    (0.12024623, 'сутки'),
#    (0.06470539, 'анкета'),
#    (0.060125217, 'дочь'),
#    (0.054937165, 'модератор'),
#    (0.026684413, 'качество'),
#    (0.021606544, 'март'),
#    (0.019852936, 'решение'),
#    (0.011539929, 'валерий'),
#    (0.010163082, 'корзина'),
#    (0.008976849, 'виктория'),
#    (0.004321792, 'стекло'),
#    (0.0013360097, 'улучшение'),
#    (0.0005873939, 'царапина'),
#    (1.8207383e-07, 'майкл'),
#    (1.8207383e-07, 'выстоновление'),
#    (1.8207383e-07, 'гениталия'),
#    (1.8207383e-07, 'последовательность')],
#   -12.286563448630988),
#  ([(0.189063, 'нарушение'),
#    (0.17678905, 'оповещение'),
#    (0.14414808, 'заметка'),
#    (0.11245537, 'версия'),
#    (0.11052655, 'возврат'),
#    (0.058625534, 'пара'),
#    (0.05385164, 'списание'),
#    (0.039823625, 'гугл'),
#    (0.024666153, 'условие'),
#    (0.020496108, 'мужчина'),
#    (0.01237928, 'угроза'),
#    (0.011995255, 'мастер'),
#    (0.01143287, 'война'),
#    (0.010198264, 'терминал'),
#    (0.0083934935, 'публичность'),
#    (0.005945245, 'тариф'),
#    (0.004069424, 'дед'),
#    (0.0021712, 'бальзам'),
#    (3.8420544e-07, 'полажила'),
#    (3.8420544e-07, 'комментирование')],
#   -12.418786793687952),
#  ([(0.35403293, 'ссылка'),
#    (0.32160127, 'регистрация'),
#    (0.054778494, 'предложение'),
#    (0.05075118, 'слово'),
#    (0.047160327, 'разработчик'),
#    (0.042944346, 'станица'),
#    (0.041941866, 'злоумышленник'),
#    (0.024018237, 'евгений'),
#    (0.017325588, 'рука'),
#    (0.012875513, 'абонент'),
#    (0.007534289, 'ноль'),
#    (0.0063666096, 'отклонение'),
#    (0.0038817278, 'удаль'),
#    (0.0035982097, 'нуль'),
#    (0.0030197427, 'другов'),
#    (0.0026803876, 'подсказка'),
#    (0.0019364023, 'профи'),
#    (0.0015500762, 'открил'),
#    (2.590909e-07, 'сериал'),
#    (2.590909e-07, 'зохадил')],
#   -13.021579276193094),
#  ([(0.59670746, 'проблема'),
#    (0.088507056, 'браузер'),
#    (0.07006633, 'жена'),
#    (0.06799206, 'устройство'),
#    (0.041901894, 'вариант'),
#    (0.03651836, 'участник'),
#    (0.03642686, 'час'),
#    (0.015417292, 'развод'),
#    (0.013150875, 'подозрение'),
#    (0.011372429, 'бред'),
#    (0.0079903165, 'хрень'),
#    (0.003490984, 'прикол'),
#    (0.003147519, 'провиль'),
#    (0.0028270576, 'зайдть'),
#    (0.0023031065, 'сити'),
#    (2.8195302e-07, 'полажила'),
#    (2.8195302e-07, 'комментирование'),
#    (2.8195302e-07, 'гениталия'),
#    (2.8195302e-07, 'цирк'),
#    (2.8195302e-07, 'калмыков')],
#   -13.635029679358961),
#  ([(0.3162286, 'фотография'),
#    (0.22832352, 'пользователь'),
#    (0.18374158, 'информация'),
#    (0.07540467, 'мама'),
#    (0.05415672, 'интернет'),
#    (0.05155917, 'контакт'),
#    (0.03030573, 'согласие'),
#    (0.02582183, 'продвижение'),
#    (0.017235242, 'брат'),
#    (0.0090923365, 'оксана'),
#    (0.005347281, 'маленькая'),
#    (0.0014440411, 'помощ'),
#    (1.7313572e-07, 'фейс'),
#    (1.7313572e-07, 'выстоновление'),
#    (1.7313572e-07, 'калмыков'),
#    (1.7313572e-07, 'гениталия'),
#    (1.7313572e-07, 'носков'),
#    (1.7313572e-07, 'сет'),
#    (1.7313572e-07, 'комментирование'),
#    (1.7313572e-07, 'майкл')],
#   -14.00459332146272),
#  ([(0.42205912, 'друг'),
#    (0.2682307, 'сообщение'),
#    (0.16092116, 'вход'),
#    (0.04353274, 'средство'),
#    (0.023319477, 'цена'),
#    (0.018148735, 'отправка'),
#    (0.018050527, 'обман'),
#    (0.016999992, 'оператор'),
#    (0.015693368, 'открытка'),
#    (0.012330305, 'перевод'),
#    (9.227491e-08, 'фейс'),
#    (9.227491e-08, 'ванна'),
#    (9.227491e-08, 'калмыков'),
#    (9.227491e-08, 'гениталия'),
#    (9.227491e-08, 'выстоновление'),
#    (9.227491e-08, 'сет'),
#    (9.227491e-08, 'комментирование'),
#    (9.227491e-08, 'цирк'),
#    (9.227491e-08, 'майкл'),
#    (9.227491e-08, 'полка')],
#   -14.138806591174838),
#  ([(0.8928151, 'логин'),
#    (0.03948046, 'покупка'),
#    (0.01897491, 'способ'),
#    (0.016200913, 'заявка'),
#    (0.008041838, 'пользование'),
#    (0.00547136, 'игорь'),
#    (0.0039385287, 'ноябрь'),
#    (0.0033245003, 'айфон'),
#    (0.0030931807, 'брак'),
#    (0.0025079767, 'михаил'),
#    (0.002249273, 'олесь'),
#    (0.0015478956, 'пётр'),
#    (0.0009912117, 'завута'),
#    (0.0008489464, 'остаток'),
#    (6.641905e-08, 'голиков'),
#    (6.641905e-08, 'полка'),
#    (6.641905e-08, 'сет'),
#    (6.641905e-08, 'калмыков'),
#    (6.641905e-08, 'гениталия'),
#    (6.641905e-08, 'комментирование')],
#   -14.140518710927187),
#  ([(0.40084344, 'игра'),
#    (0.20958847, 'список'),
#    (0.11315879, 'александр'),
#    (0.06766983, 'бонус'),
#    (0.059858274, 'карточка'),
#    (0.047174435, 'дружба'),
#    (0.034340516, 'часть'),
#    (0.03089479, 'сбой'),
#    (0.012031837, 'поисковик'),
#    (0.011413114, 'норма'),
#    (0.004841885, 'сложность'),
#    (0.0036697735, 'игрушка'),
#    (0.0016951927, 'кран'),
#    (3.6454335e-07, 'фейс'),
#    (3.6454335e-07, 'бит'),
#    (3.6454335e-07, 'цирк'),
#    (3.6454335e-07, 'полажила'),
#    (3.6454335e-07, 'носков'),
#    (3.6454335e-07, 'калмыков'),
#    (3.6454335e-07, 'клетка')],
#   -14.240877212428098),
#  ([(0.90226173, 'профиль'),
#    (0.029363977, 'статус'),
#    (0.014998686, 'утро'),
#    (0.009221521, 'елена'),
#    (0.008419744, 'поиск'),
#    (0.006781726, 'владимир'),
#    (0.0058481577, 'сторінку'),
#    (0.0053948415, 'порно'),
#    (0.005309827, 'количество'),
#    (0.0044382405, 'відновити'),
#    (0.00187784, 'логін'),
#    (0.001702653, 'ятая'),
#    (0.0016862983, 'протяжение'),
#    (0.0008596511, 'поступление'),
#    (0.0007355251, 'серьга'),
#    (0.00058109727, 'отписка'),
#    (0.00021031343, 'кулон'),
#    (3.9928526e-08, 'сериал'),
#    (3.9928526e-08, 'последовательность'),
#    (3.9928526e-08, 'дневник')],
#   -14.250305402867186),
#  ([(0.25434533, 'лента'),
#    (0.20563212, 'переписка'),
#    (0.11269203, 'активность'),
#    (0.083502635, 'подруга'),
#    (0.06390725, 'помагит'),
#    (0.06191961, 'событие'),
#    (0.056584522, 'проф'),
#    (0.035637416, 'однакласник'),
#    (0.027293561, 'неведимка'),
#    (0.024687802, 'строка'),
#    (0.021282038, 'король'),
#    (0.017333455, 'галочка'),
#    (0.011448341, 'смска'),
#    (0.007744383, 'пожалюст'),
#    (0.0072134184, 'истечение'),
#    (0.0060630925, 'намер'),
#    (3.508792e-07, 'адоба'),
#    (3.508792e-07, 'выстоновление'),
#    (3.508792e-07, 'последовательность'),
#    (3.508792e-07, 'сериал')],
#   -14.282571427884644),
#  ([(0.14563707, 'наталья'),
#    (0.13853604, 'востоновление'),
#    (0.1332643, 'жизнь'),
#    (0.12036994, 'изменение'),
#    (0.0967486, 'сервис'),
#    (0.09546501, 'название'),
#    (0.08983351, 'немаг'),
#    (0.052020483, 'переезд'),
#    (0.03713729, 'виталий'),
#    (0.02040228, 'наташа'),
#    (0.018610578, 'чёрном'),
#    (0.010718507, 'всвязь'),
#    (0.009967454, 'допуск'),
#    (0.009559293, 'влад'),
#    (0.007865724, 'владислав'),
#    (0.0051518357, 'арин'),
#    (0.0025069278, 'бондаренко'),
#    (8.026112e-07, 'калмыков'),
#    (8.026112e-07, 'гениталия'),
#    (8.026112e-07, 'майкл')],
#   -14.370463776982765),
#  ([(0.48284686, 'восстановление'),
#    (0.21754724, 'вечер'),
#    (0.1639292, 'помощь'),
#    (0.06913344, 'настройка'),
#    (0.03328298, 'комментарий'),
#    (0.012104646, 'порядок'),
#    (0.011727804, 'документ'),
#    (0.004292535, 'папка'),
#    (0.002467355, 'расширение'),
#    (0.001700264, 'волос'),
#    (1.2506541e-07, 'погремушка'),
#    (1.2506541e-07, 'полажила'),
#    (1.2506541e-07, 'комментирование'),
#    (1.2506541e-07, 'фейс'),
#    (1.2506541e-07, 'цирк'),
#    (1.2506541e-07, 'последовательность'),
#    (1.2506541e-07, 'выстоновление'),
#    (1.2506541e-07, 'адоба'),
#    (1.2506541e-07, 'калмыков'),
#    (1.2506541e-07, 'сет')],
#   -14.627367406028833),
#  ([(0.4385, 'карта'),
#    (0.15815529, 'функция'),
#    (0.12298505, 'месяц'),
#    (0.08029111, 'рождение'),
#    (0.07832686, 'дата'),
#    (0.04219886, 'место'),
#    (0.03140449, 'данные'),
#    (0.030685835, 'ночь'),
#    (0.009742134, 'проживание'),
#    (0.0066794893, 'режим'),
#    (1.3323927e-07, 'полажила'),
#    (1.3323927e-07, 'носков'),
#    (1.3323927e-07, 'погремушка'),
#    (1.3323927e-07, 'бит'),
#    (1.3323927e-07, 'цирк'),
#    (1.3323927e-07, 'можить'),
#    (1.3323927e-07, 'гениталия'),
#    (1.3323927e-07, 'фейс'),
#    (1.3323927e-07, 'хасан'),
#    (1.3323927e-07, 'калмыков')],
#   -14.631676060679464),
#  ([(0.72264826, 'день'),
#    (0.07076327, 'момент'),
#    (0.046081427, 'спам'),
#    (0.034626577, 'действие'),
#    (0.033101574, 'система'),
#    (0.031125687, 'гость'),
#    (0.023177007, 'блокировка'),
#    (0.015522383, 'форум'),
#    (0.011411191, 'саит'),
#    (0.009502856, 'продление'),
#    (0.0012261954, 'будущее'),
#    (1.0509957e-07, 'фейс'),
#    (1.0509957e-07, 'выстоновление'),
#    (1.0509957e-07, 'сет'),
#    (1.0509957e-07, 'майкл'),
#    (1.0509957e-07, 'гениталия'),
#    (1.0509957e-07, 'голиков'),
#    (1.0509957e-07, 'калмыков'),
#    (1.0509957e-07, 'цирк'),
#    (1.0509957e-07, 'полка')],
#   -14.744703471509581),
#  ([(0.25094438, 'поддержка'),
#    (0.2271713, 'служба'),
#    (0.11580625, 'ситуация'),
#    (0.11406501, 'запись'),
#    (0.0878, 'фотка'),
#    (0.052788675, 'оскорбление'),
#    (0.049917165, 'владелец'),
#    (0.046423845, 'цифра'),
#    (0.03436534, 'форма'),
#    (0.012382533, 'новий'),
#    (0.005051654, 'претензия'),
#    (0.0010972943, 'ссилок'),
#    (2.826523e-07, 'полажила'),
#    (2.826523e-07, 'цирк'),
#    (2.826523e-07, 'комментирование'),
#    (2.826523e-07, 'носков'),
#    (2.826523e-07, 'погремушка'),
#    (2.826523e-07, 'бит'),
#    (2.826523e-07, 'можить'),
#    (2.826523e-07, 'гениталия')],
#   -14.805899052554928),
#  ([(0.5444055, 'год'),
#    (0.122982375, 'россия'),
#    (0.09749958, 'письмо'),
#    (0.06890226, 'образ'),
#    (0.054191597, 'ольга'),
#    (0.035380356, 'николай'),
#    (0.03526942, 'андрей'),
#    (0.019352296, 'даное'),
#    (0.007691598, 'екатеринбург'),
#    (0.006230286, 'юмор'),
#    (0.0032470538, 'рецепт'),
#    (0.0025762182, 'миша'),
#    (2.9362872e-07, 'цирк'),
#    (2.9362872e-07, 'комментирование'),
#    (2.9362872e-07, 'бит'),
#    (2.9362872e-07, 'фейс'),
#    (2.9362872e-07, 'калмыков'),
#    (2.9362872e-07, 'гениталия'),
#    (2.9362872e-07, 'полажила'),
#    (2.9362872e-07, 'ангарск')],
#   -14.8189763363924),
#  ([(0.45691067, 'заказ'),
#    (0.3051013, 'подарок'),
#    (0.06769031, 'рубль'),
#    (0.04532517, 'сумма'),
#    (0.044137273, 'ребёнок'),
#    (0.02311748, 'течение'),
#    (0.02101849, 'число'),
#    (0.018368486, 'стоимость'),
#    (0.009830235, 'камера'),
#    (0.0047685234, 'микрофон'),
#    (0.00290222, 'разница'),
#    (1.07258174e-07, 'комментирование'),
#    (1.07258174e-07, 'бит'),
#    (1.07258174e-07, 'полажила'),
#    (1.07258174e-07, 'калмыков'),
#    (1.07258174e-07, 'погремушка'),
#    (1.07258174e-07, 'фейс'),
#    (1.07258174e-07, 'цирк'),
#    (1.07258174e-07, 'гениталия'),
#    (1.07258174e-07, 'майкл')],
#   -14.836856862476361),
#  ([(0.5603635, 'страничка'),
#    (0.30183294, 'пороль'),
#    (0.05013527, 'профеля'),
#    (0.03565406, 'пожалуста'),
#    (0.022953287, 'защита'),
#    (0.0078542195, 'проверка'),
#    (0.0072489735, 'ролик'),
#    (0.0053591114, 'ерунда'),
#    (0.004478032, 'наличие'),
#    (0.0018961957, 'скорость'),
#    (0.0014424913, 'поль'),
#    (1.0105221e-07, 'модер'),
#    (1.0105221e-07, 'майкл'),
#    (1.0105221e-07, 'гениталия'),
#    (1.0105221e-07, 'бит'),
#    (1.0105221e-07, 'цирк'),
#    (1.0105221e-07, 'фейс'),
#    (1.0105221e-07, 'комментирование'),
#    (1.0105221e-07, 'полажила'),
#    (1.0105221e-07, 'калмыков')],
#   -15.163346018192351),
#  ([(0.40348795, 'подписка'),
#    (0.22980765, 'услуга'),
#    (0.11913802, 'невидимка'),
#    (0.060457997, 'сергей'),
#    (0.042000044, 'обсуждение'),
#    (0.035516582, 'основание'),
#    (0.028464507, 'доказательство'),
#    (0.026211495, 'семья'),
#    (0.017715262, 'коментарий'),
#    (0.017278256, 'граф'),
#    (0.013706247, 'предупреждение'),
#    (0.0037665803, 'дедушка'),
#    (3.166413e-07, 'комментирование'),
#    (3.166413e-07, 'сет'),
#    (3.166413e-07, 'майкл'),
#    (3.166413e-07, 'полажила'),
#    (3.166413e-07, 'выстоновление'),
#    (3.166413e-07, 'фейс'),
#    (3.166413e-07, 'погремушка'),
#    (3.166413e-07, 'калмыков')],
#   -15.172539492850593),
#  ([(0.29411715, 'раздел'),
#    (0.22110027, 'попытка'),
#    (0.17168768, 'запрос'),
#    (0.10707074, 'повод'),
#    (0.084558845, 'экран'),
#    (0.027487336, 'добавление'),
#    (0.023557642, 'главное'),
#    (0.022085845, 'авторизация'),
#    (0.017638013, 'окошко'),
#    (0.016282577, 'заполнение'),
#    (0.009748523, 'вина'),
#    (6.030159e-07, 'полажила'),
#    (6.030159e-07, 'калмыков'),
#    (6.030159e-07, 'майкл'),
#    (6.030159e-07, 'цирк'),
#    (6.030159e-07, 'гениталия'),
#    (6.030159e-07, 'бит'),
#    (6.030159e-07, 'погремушка'),
#    (6.030159e-07, 'носков'),
#    (6.030159e-07, 'фейс')],
#   -15.179921416982191),
#  ([(0.6906571, 'одноклассник'),
#    (0.2455275, 'человек'),
#    (0.023488162, 'админ'),
#    (0.016687153, 'размер'),
#    (0.010332799, 'надежда'),
#    (0.0062078736, 'безобразие'),
#    (0.0026286892, 'ноут'),
#    (0.002570991, 'дарья'),
#    (0.0012101971, 'множество'),
#    (8.905659e-08, 'бит'),
#    (8.905659e-08, 'цирк'),
#    (8.905659e-08, 'полажила'),
#    (8.905659e-08, 'комментирование'),
#    (8.905659e-08, 'фейс'),
#    (8.905659e-08, 'сет'),
#    (8.905659e-08, 'гениталия'),
#    (8.905659e-08, 'майкл'),
#    (8.905659e-08, 'выстоновление'),
#    (8.905659e-08, 'калмыков'),
#    (8.905659e-08, 'последовательность')],
#   -15.330765102100763),
#  ([(0.24725996, 'имя'),
#    (0.22961944, 'возможность'),
#    (0.2001888, 'парол'),
#    (0.11577547, 'мера'),
#    (0.084603794, 'привет'),
#    (0.051475603, 'платёж'),
#    (0.02820127, 'долг'),
#    (0.014843108, 'памагит'),
#    (0.012980447, 'мат'),
#    (0.009032254, 'заход'),
#    (0.0043862606, 'сало'),
#    (2.1115653e-07, 'майкл'),
#    (2.1115653e-07, 'гениталия'),
#    (2.1115653e-07, 'цирк'),
#    (2.1115653e-07, 'калмыков'),
#    (2.1115653e-07, 'фейс'),
#    (2.1115653e-07, 'страх'),
#    (2.1115653e-07, 'комментирование'),
#    (2.1115653e-07, 'полажила'),
#    (2.1115653e-07, 'бит')],
#   -15.520484157279608),
#  ([(0.8047568, 'сайт'),
#    (0.050468218, 'октябрь'),
#    (0.045094788, 'неделя'),
#    (0.029798014, 'обновление'),
#    (0.02409364, 'подключение'),
#    (0.018341629, 'рабочий'),
#    (0.009556719, 'операция'),
#    (0.0075508934, 'фотошоп'),
#    (0.0065403576, 'банк'),
#    (0.002547202, 'зарядка'),
#    (1.6176566e-07, 'носков'),
#    (1.6176566e-07, 'бит'),
#    (1.6176566e-07, 'цирк'),
#    (1.6176566e-07, 'калмыков'),
#    (1.6176566e-07, 'комментирование'),
#    (1.6176566e-07, 'фейс'),
#    (1.6176566e-07, 'гениталия'),
#    (1.6176566e-07, 'майкл'),
#    (1.6176566e-07, 'полажила'),
#    (1.6176566e-07, 'погремушка')],
#   -15.735668013446311),
#  ([(0.83851016, 'доступ'),
#    (0.088566355, 'старое'),
#    (0.04331781, 'однокласник'),
#    (0.009571289, 'баланс'),
#    (0.008483821, 'ведомо'),
#    (0.0055605867, 'файл'),
#    (0.0018343903, 'тамара'),
#    (0.0014323645, 'диск'),
#    (0.0011361911, 'стол'),
#    (0.0011335787, 'минск'),
#    (5.856749e-08, 'калмыков'),
#    (5.856749e-08, 'фейс'),
#    (5.856749e-08, 'комментирование'),
#    (5.856749e-08, 'майкл'),
#    (5.856749e-08, 'полажила'),
#    (5.856749e-08, 'сет'),
#    (5.856749e-08, 'выстоновление'),
#    (5.856749e-08, 'носков'),
#    (5.856749e-08, 'гениталия'),
#    (5.856749e-08, 'цирк')],
#   -15.987774186338083),
#  ([(0.42636776, 'причина'),
#    (0.20222792, 'пост'),
#    (0.114182346, 'июнь'),
#    (0.05747933, 'отделение'),
#    (0.05471411, 'модерация'),
#    (0.046394136, 'приглашение'),
#    (0.046162944, 'строничек'),
#    (0.021379368, 'максим'),
#    (0.016283695, 'краснодар'),
#    (0.0070473943, 'аукцион'),
#    (0.0045593865, 'отчёт'),
#    (4.138164e-07, 'комментирование'),
#    (4.138164e-07, 'полажила'),
#    (4.138164e-07, 'гениталия'),
#    (4.138164e-07, 'сет'),
#    (4.138164e-07, 'майкл'),
#    (4.138164e-07, 'выстоновление'),
#    (4.138164e-07, 'фейс'),
#    (4.138164e-07, 'ангарск'),
#    (4.138164e-07, 'калмыков')],
#   -16.063725185996688),
#  ([(0.6767699, 'деньга'),
#    (0.1540603, 'код'),
#    (0.06981883, 'оплата'),
#    (0.068294585, 'новое'),
#    (0.01862409, 'значок'),
#    (0.009182627, 'первое'),
#    (0.0013822162, 'этап'),
#    (0.00073957944, 'пакетик'),
#    (1.4574421e-07, 'калмыков'),
#    (1.4574421e-07, 'майкл'),
#    (1.4574421e-07, 'сет'),
#    (1.4574421e-07, 'выстоновление'),
#    (1.4574421e-07, 'фейс'),
#    (1.4574421e-07, 'комментирование'),
#    (1.4574421e-07, 'полажила'),
#    (1.4574421e-07, 'цирк'),
#    (1.4574421e-07, 'бит'),
#    (1.4574421e-07, 'погремушка'),
#    (1.4574421e-07, 'гениталия'),
#    (1.4574421e-07, 'полка')],
#   -16.098470639983034),
#  ([(0.37570974, 'компьютер'),
#    (0.29211962, 'город'),
#    (0.117674045, 'татьяна'),
#    (0.07484757, 'область'),
#    (0.06446279, 'однаклассник'),
#    (0.03876689, 'район'),
#    (0.020999357, 'сервер'),
#    (0.008138863, 'ключ'),
#    (0.0034253998, 'ппроль'),
#    (4.9824797e-07, 'носков'),
#    (4.9824797e-07, 'погремушка'),
#    (4.9824797e-07, 'бит'),
#    (4.9824797e-07, 'цирк'),
#    (4.9824797e-07, 'майкл'),
#    (4.9824797e-07, 'сет'),
#    (4.9824797e-07, 'фейс'),
#    (4.9824797e-07, 'калмыков'),
#    (4.9824797e-07, 'гениталия'),
#    (4.9824797e-07, 'полажила'),
#    (4.9824797e-07, 'комментирование')],
#   -16.09850712246305),
#  ([(0.96579045, 'почта'),
#    (0.009501785, 'родственник'),
#    (0.008154274, 'аватарка'),
#    (0.00674454, 'рамка'),
#    (0.0032002276, 'край'),
#    (0.0031865719, 'лариса'),
#    (0.0027183553, 'мэйл'),
#    (0.00024267918, 'захажа'),
#    (5.95466e-08, 'погремушка'),
#    (5.95466e-08, 'бит'),
#    (5.95466e-08, 'цирк'),
#    (5.95466e-08, 'фейс'),
#    (5.95466e-08, 'комментирование'),
#    (5.95466e-08, 'калмыков'),
#    (5.95466e-08, 'гениталия'),
#    (5.95466e-08, 'майкл'),
#    (5.95466e-08, 'сет'),
#    (5.95466e-08, 'выстоновление'),
#    (5.95466e-08, 'полажила'),
#    (5.95466e-08, 'последовательность')],
#   -16.109126125619238),
#  ([(0.50462997, 'номер'),
#    (0.4605593, 'телефон'),
#    (0.020012649, 'просьба'),
#    (0.009412867, 'ящик'),
#    (0.00418097, 'программа'),
#    (0.0007304156, 'снятие'),
#    (0.00035936816, 'двойник'),
#    (1.4824409e-08, 'цирк'),
#    (1.4824409e-08, 'полажила'),
#    (1.4824409e-08, 'комментирование'),
#    (1.4824409e-08, 'фейс'),
#    (1.4824409e-08, 'калмыков'),
#    (1.4824409e-08, 'выстоновление'),
#    (1.4824409e-08, 'майкл'),
#    (1.4824409e-08, 'сет'),
#    (1.4824409e-08, 'осетия'),
#    (1.4824409e-08, 'последовательность'),
#    (1.4824409e-08, 'бит'),
#    (1.4824409e-08, 'гениталия'),
#    (1.4824409e-08, 'пароьь')],
#   -16.16289648307299),
#  ([(0.98955804, 'страница'),
#    (0.009063571, 'работа'),
#    (0.0011061109, 'неполадка'),
#    (3.519315e-08, 'можить'),
#    (3.519315e-08, 'страх'),
#    (3.519315e-08, 'выстоновление'),
#    (3.519315e-08, 'ангарск'),
#    (3.519315e-08, 'носков'),
#    (3.519315e-08, 'погремушка'),
#    (3.519315e-08, 'бит'),
#    (3.519315e-08, 'цирк'),
#    (3.519315e-08, 'комментирование'),
#    (3.519315e-08, 'осетия'),
#    (3.519315e-08, 'фейс'),
#    (3.519315e-08, 'калмыков'),
#    (3.519315e-08, 'гениталия'),
#    (3.519315e-08, 'майкл'),
#    (3.519315e-08, 'муха'),
#    (3.519315e-08, 'полажила'),
#    (3.519315e-08, 'возрост')],
#   -16.182581391314734),
#  ([(0.78883785, 'аккаунт'),
#    (0.1062005, 'подтверждение'),
#    (0.09370822, 'сожаление'),
#    (0.006347418, 'желание'),
#    (0.0037577946, 'ход'),
#    (1.4831066e-07, 'выстоновление'),
#    (1.4831066e-07, 'носков'),
#    (1.4831066e-07, 'погремушка'),
#    (1.4831066e-07, 'бит'),
#    (1.4831066e-07, 'цирк'),
#    (1.4831066e-07, 'ангарск'),
#    (1.4831066e-07, 'пароьь'),
#    (1.4831066e-07, 'комментирование'),
#    (1.4831066e-07, 'фейс'),
#    (1.4831066e-07, 'калмыков'),
#    (1.4831066e-07, 'гениталия'),
#    (1.4831066e-07, 'майкл'),
#    (1.4831066e-07, 'модер'),
#    (1.4831066e-07, 'полажила'),
#    (1.4831066e-07, 'село')],
#   -16.41609509762728),
#  ([(0.99207324, 'пароль'),
#    (0.006507494, 'ввод'),
#    (0.00064529805, 'наталия'),
#    (0.0005668385, 'сохранение'),
#    (2.6791499e-08, 'ангарск'),
#    (2.6791499e-08, 'можить'),
#    (2.6791499e-08, 'выстоновление'),
#    (2.6791499e-08, 'носков'),
#    (2.6791499e-08, 'погремушка'),
#    (2.6791499e-08, 'бит'),
#    (2.6791499e-08, 'цирк'),
#    (2.6791499e-08, 'комментирование'),
#    (2.6791499e-08, 'пароьь'),
#    (2.6791499e-08, 'фейс'),
#    (2.6791499e-08, 'калмыков'),
#    (2.6791499e-08, 'гениталия'),
#    (2.6791499e-08, 'майкл'),
#    (2.6791499e-08, 'модер'),
#    (2.6791499e-08, 'полажила'),
#    (2.6791499e-08, 'село')],
#   -16.45164590316954),
#  ([(0.4172061, 'приложение'),
#    (0.2545493, 'акаунт'),
#    (0.116476886, 'муж'),
#    (0.07957783, 'строница'),
#    (0.0240776, 'счёте'),
#    (0.022635022, 'знакомство'),
#    (0.021816805, 'эмейл'),
#    (0.018800331, 'люба'),
#    (0.017221816, 'сторінки'),
#    (0.014744717, 'специалист'),
#    (0.009487436, 'птица'),
#    (4.402615e-07, 'бит'),
#    (4.402615e-07, 'полажила'),
#    (4.402615e-07, 'цирк'),
#    (4.402615e-07, 'майкл'),
#    (4.402615e-07, 'гениталия'),
#    (4.402615e-07, 'сет'),
#    (4.402615e-07, 'выстоновление'),
#    (4.402615e-07, 'калмыков'),
#    (4.402615e-07, 'комментирование')],
#   -16.552466407799827),
#  ([(0.6815499, 'звонок'),
#    (0.15893358, 'скайп'),
#    (0.12826799, 'запрет'),
#    (4.03465e-06, 'модер'),
#    (4.03465e-06, 'возрост'),
#    (4.03465e-06, 'муха'),
#    (4.03465e-06, 'гениталия'),
#    (4.03465e-06, 'страх'),
#    (4.03465e-06, 'можить'),
#    (4.03465e-06, 'ангарск'),
#    (4.03465e-06, 'носков'),
#    (4.03465e-06, 'бит'),
#    (4.03465e-06, 'приоритет'),
#    (4.03465e-06, 'цирк'),
#    (4.03465e-06, 'полажила'),
#    (4.03465e-06, 'комментирование'),
#    (4.03465e-06, 'фейс'),
#    (4.03465e-06, 'ригистрация'),
#    (4.03465e-06, 'погремушка'),
#    (4.03465e-06, 'осетия')],
#   -16.580868433518862),
#  ([(0.8537651, 'товар'),
#    (0.103310004, 'окова'),
#    (0.028095236, 'часы'),
#    (0.010721999, 'сведение'),
#    (0.0027462582, 'движение'),
#    (1.7582904e-07, 'ангарск'),
#    (1.7582904e-07, 'выстоновление'),
#    (1.7582904e-07, 'погремушка'),
#    (1.7582904e-07, 'бит'),
#    (1.7582904e-07, 'цирк'),
#    (1.7582904e-07, 'носков'),
#    (1.7582904e-07, 'пароьь'),
#    (1.7582904e-07, 'комментирование'),
#    (1.7582904e-07, 'фейс'),
#    (1.7582904e-07, 'калмыков'),
#    (1.7582904e-07, 'гениталия'),
#    (1.7582904e-07, 'майкл'),
#    (1.7582904e-07, 'сет'),
#    (1.7582904e-07, 'полажила'),
#    (1.7582904e-07, 'село')],
#   -16.625774889773265),
#  ([(0.2961635, 'профил'),
#    (0.2949062, 'счёт'),
#    (0.14622268, 'посылка'),
#    (0.14445382, 'правило'),
#    (0.060387854, 'сбербанк'),
#    (0.04540085, 'надпись'),
#    (0.0050786384, 'табличка'),
#    (0.0045988816, 'пиш'),
#    (3.6016536e-07, 'носков'),
#    (3.6016536e-07, 'погремушка'),
#    (3.6016536e-07, 'бит'),
#    (3.6016536e-07, 'цирк'),
#    (3.6016536e-07, 'калмыков'),
#    (3.6016536e-07, 'комментирование'),
#    (3.6016536e-07, 'фейс'),
#    (3.6016536e-07, 'выстоновление'),
#    (3.6016536e-07, 'гениталия'),
#    (3.6016536e-07, 'майкл'),
#    (3.6016536e-07, 'полажила'),
#    (3.6016536e-07, 'пароьь')],
#   -16.7922925150651),
#  ([(0.4613667, 'ошибка'),
#    (0.33554274, 'смена'),
#    (0.16514361, 'пороля'),
#    (0.027879165, 'приватность'),
#    (0.0035535123, 'проба'),
#    (8.413287e-07, 'гениталия'),
#    (8.413287e-07, 'фейс'),
#    (8.413287e-07, 'комментирование'),
#    (8.413287e-07, 'полажила'),
#    (8.413287e-07, 'село'),
#    (8.413287e-07, 'цирк'),
#    (8.413287e-07, 'бит'),
#    (8.413287e-07, 'погремушка'),
#    (8.413287e-07, 'носков'),
#    (8.413287e-07, 'ангарск'),
#    (8.413287e-07, 'можить'),
#    (8.413287e-07, 'сет'),
#    (8.413287e-07, 'пароьь'),
#    (8.413287e-07, 'калмыков'),
#    (8.413287e-07, 'полка')],
#   -16.80238277821502)]

# %%
# Train LDA model.
num_topics = 6
chunksize = 2000
passes = 40
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

# %time model6 = LdaModel(corpus=corpus, id2word=id2word, chunksize=chunksize, \
                       alpha='auto', eta='auto', \
                       iterations=iterations, num_topics=num_topics, \
                       passes=passes, eval_every=eval_every)

top_topics6 = model6.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence6 = sum([t[1] for t in top_topics6]) / num_topics
# Out:
# CPU times: user 8h 28min 21s, sys: 12min 40s, total: 8h 41min 2s
# Wall time: 4h 48min 45s

# %%
print('Average topic coherence: %.4f.' % avg_topic_coherence6)

from pprint import pprint
pprint(top_topics6)
# Out:
# Average topic coherence: -4.8613.
# [([(0.07301616, 'аккаунт'),
#    (0.06279059, 'друг'),
#    (0.0618271, 'фото'),
#    (0.039905153, 'сообщение'),
#    (0.037847664, 'человек'),
#    (0.026218574, 'время'),
#    (0.02507362, 'фотография'),
#    (0.018758155, 'ссылка'),
#    (0.018532624, 'просьба'),
#    (0.018103696, 'пользователь'),
#    (0.016074993, 'имя'),
#    (0.014568619, 'информация'),
#    (0.013612544, 'вопрос'),
#    (0.012187711, 'поддержка'),
#    (0.011232305, 'ответ'),
#    (0.011033092, 'служба'),
#    (0.010284146, 'сайт'),
#    (0.00944199, 'уважение'),
#    (0.00906602, 'сутки'),
#    (0.008298538, 'доставка')],
#   -3.6059850919225034),
#  ([(0.11447515, 'деньга'),
#    (0.105017744, 'заказ'),
#    (0.081133194, 'карта'),
#    (0.07012546, 'подарок'),
#    (0.022755109, 'месяц'),
#    (0.020185603, 'счёт'),
#    (0.018130176, 'статус'),
#    (0.017891807, 'услуга'),
#    (0.017869743, 'лента'),
#    (0.015558283, 'рубль'),
#    (0.014855487, 'рождение'),
#    (0.014492383, 'дата'),
#    (0.014484533, 'окова'),
#    (0.013714912, 'реклама'),
#    (0.013626967, 'настройка'),
#    (0.0121303955, 'нарушение'),
#    (0.011809829, 'оплата'),
#    (0.011630645, 'средство'),
#    (0.011343357, 'оповещение'),
#    (0.01041782, 'сумма')],
#   -4.443727257443523),
#  ([(0.43074048, 'пароль'),
#    (0.15636435, 'логин'),
#    (0.09021205, 'одноклассник'),
#    (0.06450477, 'страничка'),
#    (0.04915468, 'сайт'),
#    (0.024617692, 'проблема'),
#    (0.020286027, 'вход'),
#    (0.012790397, 'игра'),
#    (0.011022919, 'приложение'),
#    (0.007386133, 'ящик'),
#    (0.0063785166, 'ошибка'),
#    (0.0057710335, 'профеля'),
#    (0.005450562, 'новое'),
#    (0.0046389415, 'смена'),
#    (0.0042646956, 'попытка'),
#    (0.0036634784, 'система'),
#    (0.0036511794, 'браузер'),
#    (0.0035093632, 'модератор'),
#    (0.0032807062, 'программа'),
#    (0.0028254667, 'ввод')],
#   -4.890758039788525),
#  ([(0.2691894, 'номер'),
#    (0.24568045, 'телефон'),
#    (0.1786946, 'профиль'),
#    (0.11321762, 'доступ'),
#    (0.023620091, 'пороль'),
#    (0.011958398, 'старое'),
#    (0.007818692, 'возможность'),
#    (0.0074970126, 'парол'),
#    (0.0074669276, 'связь'),
#    (0.0065024537, 'профил'),
#    (0.0059626964, 'компьютер'),
#    (0.0053242296, 'момент'),
#    (0.004996339, 'сожаление'),
#    (0.0046360213, 'город'),
#    (0.00425654, 'востановление'),
#    (0.0033117922, 'россия'),
#    (0.0031712533, 'правило'),
#    (0.002970352, 'утро'),
#    (0.0027900252, 'пожалуста'),
#    (0.0021908057, 'страна')],
#   -5.237818955291092),
#  ([(0.345039, 'страница'),
#    (0.19902618, 'почта'),
#    (0.084374234, 'день'),
#    (0.05958412, 'товар'),
#    (0.047375686, 'восстановление'),
#    (0.025043698, 'адрес'),
#    (0.022751024, 'год'),
#    (0.015231509, 'регистрация'),
#    (0.013834234, 'помощь'),
#    (0.012971103, 'код'),
#    (0.0087867575, 'подтверждение'),
#    (0.0062288074, 'симка'),
#    (0.0059010196, 'срок'),
#    (0.0052195434, 'симкарта'),
#    (0.0040519945, 'дочь'),
#    (0.0036540132, 'контакт'),
#    (0.0035056048, 'способ'),
#    (0.003385514, 'июнь'),
#    (0.0030491278, 'жена'),
#    (0.0029768003, 'муж')],
#   -5.438469847231863),
#  ([(0.091077425, 'группа'),
#    (0.062330015, 'вечер'),
#    (0.0456609, 'подписка'),
#    (0.042533845, 'функция'),
#    (0.03691921, 'причина'),
#    (0.02821393, 'видео'),
#    (0.026503058, 'однокласник'),
#    (0.02606509, 'музыка'),
#    (0.022584543, 'тема'),
#    (0.02071715, 'акаунт'),
#    (0.020510046, 'дело'),
#    (0.01751095, 'пост'),
#    (0.017476888, 'раздел'),
#    (0.015395486, 'администрация'),
#    (0.014547293, 'посылка'),
#    (0.014356827, 'привет'),
#    (0.013482146, 'невидимка'),
#    (0.013443647, 'заметка'),
#    (0.012734, 'анкета'),
#    (0.010487751, 'версия')],
#   -5.550909974152721)]

# %%
# Train LDA model.
num_topics = 7
chunksize = 2000
passes = 40
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make a index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

# %time model7 = LdaModel(corpus=corpus, id2word=id2word, chunksize=chunksize, \
                       alpha='auto', eta='auto', \
                       iterations=iterations, num_topics=num_topics, \
                       passes=passes, eval_every=eval_every)

top_topics7 = model7.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence7 = sum([t[1] for t in top_topics7]) / num_topics
# Out:
# CPU times: user 11h 15min 42s, sys: 19min 21s, total: 11h 35min 3s
# Wall time: 4h 3min 53s

# %%
print('Average topic coherence: %.4f.' % avg_topic_coherence7)

from pprint import pprint
pprint(top_topics7)
# Out:
# Average topic coherence: -5.1921.
# [([(0.10347928, 'сайт'),
#    (0.095140375, 'друг'),
#    (0.09368055, 'фото'),
#    (0.052869245, 'группа'),
#    (0.044020597, 'проблема'),
#    (0.027430715, 'пользователь'),
#    (0.022871621, 'игра'),
#    (0.021430962, 'причина'),
#    (0.018466907, 'поддержка'),
#    (0.016717417, 'служба'),
#    (0.015384427, 'однокласник'),
#    (0.015077662, 'лента'),
#    (0.014306467, 'уважение'),
#    (0.013109927, 'тема'),
#    (0.012364006, 'покупка'),
#    (0.011958632, 'список'),
#    (0.011905642, 'дело'),
#    (0.010164698, 'пост'),
#    (0.010144973, 'раздел'),
#    (0.009570879, 'оповещение')],
#   -4.11909563266866),
#  ([(0.3621485, 'страница'),
#    (0.08855813, 'день'),
#    (0.062538706, 'товар'),
#    (0.02628546, 'адрес'),
#    (0.023879247, 'год'),
#    (0.023524137, 'фотография'),
#    (0.022403449, 'вечер'),
#    (0.017598957, 'ссылка'),
#    (0.017387396, 'просьба'),
#    (0.016881738, 'помощь'),
#    (0.015081527, 'имя'),
#    (0.014005476, 'возможность'),
#    (0.013668314, 'информация'),
#    (0.010538174, 'ответ'),
#    (0.009368404, 'музыка'),
#    (0.008526411, 'срок'),
#    (0.007330768, 'мошенник'),
#    (0.0070615546, 'мера'),
#    (0.0069326214, 'востановление'),
#    (0.0061021503, 'фамилия')],
#   -4.6124189772027435),
#  ([(0.23384674, 'пароль'),
#    (0.21497105, 'номер'),
#    (0.19619705, 'телефон'),
#    (0.102425896, 'почта'),
#    (0.09041411, 'доступ'),
#    (0.03358905, 'аккаунт'),
#    (0.02438118, 'восстановление'),
#    (0.009549796, 'старое'),
#    (0.007838652, 'регистрация'),
#    (0.006675357, 'код'),
#    (0.005962973, 'связь'),
#    (0.0045219343, 'подтверждение'),
#    (0.00425183, 'момент'),
#    (0.003989997, 'сожаление'),
#    (0.0026861415, 'симкарта'),
#    (0.0025184473, 'смена'),
#    (0.0019887732, 'система'),
#    (0.0018803857, 'контакт'),
#    (0.001749517, 'страна'),
#    (0.0012431113, 'комп')],
#   -4.6571670375262535),
#  ([(0.09110921, 'сообщение'),
#    (0.08915632, 'подарок'),
#    (0.086411566, 'человек'),
#    (0.059860975, 'время'),
#    (0.039939072, 'подписка'),
#    (0.037203956, 'функция'),
#    (0.031079583, 'вопрос'),
#    (0.024678417, 'видео'),
#    (0.022747194, 'услуга'),
#    (0.020699326, 'сутки'),
#    (0.018946985, 'доставка'),
#    (0.018415572, 'окова'),
#    (0.018367823, 'переписка'),
#    (0.017436998, 'реклама'),
#    (0.017325314, 'настройка'),
#    (0.011058419, 'пожалуста'),
#    (0.010295261, 'администратор'),
#    (0.009282306, 'гость'),
#    (0.008251462, 'история'),
#    (0.0077881697, 'жена')],
#   -5.137450873039841),
#  ([(0.13318413, 'страничка'),
#    (0.11152658, 'деньга'),
#    (0.102312796, 'заказ'),
#    (0.07904344, 'карта'),
#    (0.07173795, 'пороль'),
#    (0.022168918, 'месяц'),
#    (0.019665472, 'счёт'),
#    (0.017663058, 'статус'),
#    (0.01515744, 'рубль'),
#    (0.014472864, 'рождение'),
#    (0.014119069, 'дата'),
#    (0.012191278, 'симка'),
#    (0.011915704, 'профеля'),
#    (0.011818094, 'нарушение'),
#    (0.0115055265, 'оплата'),
#    (0.011330974, 'средство'),
#    (0.010318661, 'администрация'),
#    (0.010294944, 'июль'),
#    (0.010149368, 'сумма'),
#    (0.009622659, 'привет')],
#   -5.426207313829792),
#  ([(0.41153544, 'профиль'),
#    (0.24480864, 'логин'),
#    (0.014975329, 'профил'),
#    (0.01373237, 'компьютер'),
#    (0.011563972, 'ящик'),
#    (0.0106770815, 'город'),
#    (0.008533623, 'новое'),
#    (0.007984861, 'спам'),
#    (0.007627352, 'россия'),
#    (0.007371732, 'сентябрь'),
#    (0.007303913, 'правило'),
#    (0.006046819, 'письмо'),
#    (0.0059209066, 'чёрный'),
#    (0.005848713, 'активность'),
#    (0.0054946383, 'модератор'),
#    (0.005463002, 'подписчик'),
#    (0.0052027567, 'способ'),
#    (0.004846308, 'комментарий'),
#    (0.0047362857, 'утерен'),
#    (0.0043908935, 'майла')],
#   -6.0003703377398345),
#  ([(0.34804803, 'одноклассник'),
#    (0.07826601, 'вход'),
#    (0.042547666, 'парол'),
#    (0.04252821, 'приложение'),
#    (0.02630263, 'сеть'),
#    (0.025947385, 'акаунт'),
#    (0.024609841, 'ошибка'),
#    (0.018386843, 'ситуация'),
#    (0.018219862, 'посылка'),
#    (0.016454346, 'попытка'),
#    (0.014819684, 'дочь'),
#    (0.014785918, 'действие'),
#    (0.014000875, 'октябрь'),
#    (0.012625966, 'паспорт'),
#    (0.012435619, 'взлом'),
#    (0.011141477, 'трек'),
#    (0.0109013785, 'ввод'),
#    (0.008985509, 'скрин'),
#    (0.008967297, 'планшет'),
#    (0.0087943785, 'число')],
#   -6.392051438555582)]
